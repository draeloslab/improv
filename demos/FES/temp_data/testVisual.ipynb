# %%
import numpy as np
import matplotlib as mpl

latencies = np.load('/home/jakejoseph/Desktop/Joseph_Code/improv/latencies.npy')
mpl.rcParams['figure.dpi'] = 150

# %%
from matplotlib import pyplot as plt

# plt.figure(figsize=(10, 10))
plt.plot(latencies)
# plt.plot(1/latencies2, label='1', alpha=0.8)
# plt.plot(1/latencies3, label='0.5 with DLC Resize', alpha=0.8)
plt.legend()

plt.ylabel('1/latency')
plt.xlabel('Frame')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'Frame')

# %%
predictions = np.load('predictions.npy')

# %%
import dlclive
dlclive.benchmark_videos('/home/jakejoseph/Desktop/AllAngles-Jake-2024-07-30/exported-models/DLC_AllAngles_mobilenet_v2_1.0_iteration-0_shuffle-1',
                          '/home/jakejoseph/Desktop/Joseph_Code/FESFatigue-Jake-2024-05-31/videos/napierecrbfatigue_05_31_3_1.mp4',
                            resize=0.5, pcutoff=0.5, display_radius=20, cmap='bmy', save_poses=True, save_video=True,output='/home/jakejoseph/Desktop/Joseph_Code/improv/demos/FES', dynamic= (True, 0.9, 10) )
# Out:
# Run 1 / 1
# 2024-08-27 15:25:11.927187: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-27 15:25:11.930097: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-27 15:25:11.931868: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-27 15:25:11.933633: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
import pandas as pd
df = pd.read_pickle('/home/jakejoseph/Desktop/Joseph_Code/improv/demos/FES/benchmark_eros_GPU_1.pickle')
df0 = pd.read_pickle('/home/jakejoseph/Desktop/Joseph_Code/improv/demos/FES/benchmark_eros_GPU_0.pickle')
df1 = pd.read_pickle('/home/jakejoseph/Desktop/Joseph_Code/improv/demos/FES/benchmark_eros_GPU_2.pickle')

#0 is (True, 0.9,30 )
#1 is (True, 0.9, 100)
#2 is (True, 0.9, 10)

# %%
from matplotlib import pyplot as plt
plt.plot(1/df['inference_times'][0], label='100', alpha=0.8)
plt.plot(1/df0['inference_times'][0], label='30', alpha=0.8)
plt.plot(1/df1['inference_times'][0], label='10', alpha=0.8)
plt.xlabel('Frame')
plt.ylabel('Frames Per Second')
plt.title('Inference Time)')
plt.legend()
plt.show()

# %%
import h5py

# Open the h5 file
file = h5py.File('/home/jakejoseph/Desktop/Joseph_Code/improv/demos/FES/napierecrbfatigue_05_31_3_1_DLCLIVE_POSES.h5', 'r')

# Access the data within the h5 file
data = file['df_with_missing']

# %%
import deeplabcut
deeplabcut.export_model(cfg_path='/home/jakejoseph/Desktop/HumanHand-Jake-2024-07-16/config.yaml', snapshotindex=-1, TFGPUinference=True, make_tar=False)
# Out:
# Loading DLC 2.3.10...
# /home/jakejoseph/anaconda3/envs/DEEPLABCUT_LIVE/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# 2024-08-27 15:44:28.510442: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-08-27 15:44:28.512875: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
